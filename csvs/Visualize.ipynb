# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df_imu = pd.read_csv("imu_odom.csv")
df_orb = pd.read_csv("orb_odom.csv")

# %%
x,y = df_imu.x.values, df_imu.y.values
x2,y2 = df_orb.x.values, df_orb.y.values

# %%
plt.plot(y, x, 'bo', y2, x2, 'go')
